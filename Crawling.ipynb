# %%
import tweepy
import csv

# %%
from tweepy import OAuthHandler
consumer_key = 'JGkmiIR6Dh5eZ8PRCDfyB7tlQ'
consumer_secret = 'mbxYaxCzzSjG2QnGDYWxEFHTovi76kDbhIDjNfHMp2eMmsF8ur'
access_token = '1220241467798482944-bIRMOJGTlEjXIlUDRiQMtoXjcIDpSC'
access_secret = '9RMN4FyHh0crNHSeV53OIUOoPZN30qomVtDe8ZEtHTEVj'

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#api = tweepy.API(auth)

# %%
csvFile = open('@IndiHome.csv', 'a')
csvWriter = csv.writer(csvFile)

# %%
for tweet in tweepy.Cursor(api.search,
                           q="@IndiHome", count=100,
                           lang="id",
                           since="2020-12-02").items():
                           #until="2020-06-12")

    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at,tweet.text.encode('utf-8')])
# Out:
# 2021-01-02 13:25:25 @andrerizqonm @IndiHome @TelkomCare @KemenBUMN Segera berganti ke myrepublic pak
# 2021-01-02 13:23:32 Niat mo kerja drmh. Buka laptop. Sambil nonton @NetflixID eh malah @IndiHome nya kayak siput.. Ulalalaaaaa....
# 2021-01-02 13:23:17 @IndiHome TOLONG DM DIJAWAB
# 2021-01-02 13:22:41 Ini @IndiHome lg knpa ya. Knpa kayak keong 😭😭😭
# 2021-01-02 13:20:51 @IndiHome Belum ada beb
# 2021-01-02 13:17:41 @emo_sian Mosi mosi, kok lu kyak tai sih @IndiHome
# 2021-01-02 13:16:31 @IndiHome halo kak, mau tanya dong. saya bisa migrasi paket nih, dari triple play ke internet saja. itu gimana ya? terima kasih.
# 2021-01-02 13:16:24 @IndiHome hallo selamat malam saya mau berhenti langganan indihome tolong dibantu ya
# 2021-01-02 13:16:10 @IndiHome sinyal nya dari tadi astagfirullah min😃👍🏻
# 2021-01-02 13:15:17 @IndiHome Oke ka ditunggu masa bayar mahal lemot
# 2021-01-02 13:15:10 @IndiHome okh kack
# 2021-01-02 13:14:30 @IndiHome kalah cepet sama covid
# ...
